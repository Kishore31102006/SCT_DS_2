# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishore31102006/SCT_DS_2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_excel("titanic.xlsx")

# View first 5 rows
df.head()
# Dataset shape
print("Rows & Columns:", df.shape)

# Column names
print("Columns:", df.columns)

# Data types and missing values
df.info()

# Statistical summary
df.describe()
print(df.isnull().sum())
# Fill missing Age with median
if 'Age' in df.columns:
    df['Age'] = df['Age'].fillna(df['Age'].median())

# Fill missing Embarked with mode
if 'Embarked' in df.columns:
    df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Drop Cabin column if it exists (too many missing values)
if 'Cabin' in df.columns:
    df = df.drop(columns=['Cabin'])
if 'Survived' in df.columns:
    sns.countplot(x='Survived', data=df)
    plt.title('Survival Count')
    plt.show()
if 'Sex' in df.columns:
    sns.countplot(x='Sex', hue='Survived', data=df)
    plt.title('Gender vs Survival')
    plt.show()
if 'Age' in df.columns:
    plt.hist(df['Age'], bins=20)
    plt.title('Age Distribution')
    plt.xlabel('Age')
    plt.ylabel('Count')
    plt.show()
if 'Pclass' in df.columns:
    sns.countplot(x='Pclass', hue='Survived', data=df)
    plt.title('Passenger Class vs Survival')
    plt.show()
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
#      <input type="file" id="files-64040937-3518-480a-a48c-54acbca1b5a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64040937-3518-480a-a48c-54acbca1b5a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
